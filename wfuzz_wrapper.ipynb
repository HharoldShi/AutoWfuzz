# %%
from urllib.request import urlopen
import urllib
from bs4 import BeautifulSoup
import re


def scrape(url):
    try:
        page = urlopen(url)
    except urllib.error.HTTPError as e:
        print('HTTPError: {}'.format(e.code))
        return None,None
    html = page.read().decode("utf-8")
    soup = BeautifulSoup(html, "html.parser")
    urls = find_url(soup,url)
    forms = find_form(soup,url)
    
    return urls, forms
    
    
def find_url(soup,url):
    if url[-1]!='/':
        url = url+'/'
        
    links=soup.find_all("a")
    sub_urls = []
    for link in links:
        i = link["href"]
        i = re.sub(r"\/*","",i)
        if re.match("http",i):
            pass
        elif re.match("mailto:",i):
            pass
        else:
            sub_urls.append(url+i)
    return sub_urls
            
def find_form(soup,url):
    if url[-1]!='/':
        url = url+'/'
        
    forms = soup.find_all('form')
    actions = {}
    for form in forms:
        actions[url+form['action']] = []
        #print(form['action'])
        #print("-----------------")
        for element in form.find_all('input'):
            if re.search('name',  str(element)):
                actions[url+form['action']].append(element['name'])
                #print(element['name'])
    return actions

# %%
urls,forms = scrape('http://testphp.vulnweb.com/login.php')

# all the sub-urls
print(urls)

# all the forms on the page
print(forms)
# Out:
# ['http://testphp.vulnweb.com/login.php/index.php', 'http://testphp.vulnweb.com/login.php/categories.php', 'http://testphp.vulnweb.com/login.php/artists.php', 'http://testphp.vulnweb.com/login.php/disclaimer.php', 'http://testphp.vulnweb.com/login.php/cart.php', 'http://testphp.vulnweb.com/login.php/guestbook.php', 'http://testphp.vulnweb.com/login.php/AJAXindex.php', 'http://testphp.vulnweb.com/login.php/signup.php', 'http://testphp.vulnweb.com/login.php/categories.php', 'http://testphp.vulnweb.com/login.php/artists.php', 'http://testphp.vulnweb.com/login.php/cart.php', 'http://testphp.vulnweb.com/login.php/login.php', 'http://testphp.vulnweb.com/login.php/userinfo.php', 'http://testphp.vulnweb.com/login.php/guestbook.php', 'http://testphp.vulnweb.com/login.php/AJAXindex.php', 'http://testphp.vulnweb.com/login.php/privacy.php']
# ...

# %%
top_url= "http://testphp.vulnweb.com/"
urls = {top_url}
visited = set()
forms = dict()

def web_scraping():
    temp_urls = set()
    if len(urls)<=len(visited):
        return
    for u in urls:
        print(u)
        if u not in visited:
            url,form = scrape(u)
            if url:
                for i in url:
                    temp_urls.add(i)
            if form:
                forms.update(form)
            visited.add(u)
    urls.update(temp_urls)
    return web_scraping()

# %%
web_scraping()
# Out:
# http://testphp.vulnweb.com/
# http://testphp.vulnweb.com/userinfo.php
# http://testphp.vulnweb.com/
# http://testphp.vulnweb.com/login.php
# http://testphp.vulnweb.com/artists.php
# http://testphp.vulnweb.com/cart.php
# http://testphp.vulnweb.com/privacy.php
# HTTPError: 404
# http://testphp.vulnweb.com/guestbook.php
# http://testphp.vulnweb.com/disclaimer.php
# http://testphp.vulnweb.com/AJAXindex.php
# HTTPError: 404
# http://testphp.vulnweb.com/Mod_Rewrite_Shop
# http://testphp.vulnweb.com/categories.php
# http://testphp.vulnweb.com/hpp
# http://testphp.vulnweb.com/index.php
# http://testphp.vulnweb.com/userinfo.php/cart.php
# HTTPError: 302
# http://testphp.vulnweb.com/disclaimer.php/cart.php
# http://testphp.vulnweb.com/cart.php
# http://testphp.vulnweb.com/userinfo.php/signup.php
# HTTPError: 302
# http://testphp.vulnweb.com/categories.php/userinfo.php
# http://testphp.vulnweb.com/login.php/guestbook.php
# http://testphp.vulnweb.com/artists.php/guestbook.php
# ...

# %%
urls
# Out:
# {'http://testphp.vulnweb.com/',
#  'http://testphp.vulnweb.com/AJAXindex.php',
#  'http://testphp.vulnweb.com/Mod_Rewrite_Shop',
#  'http://testphp.vulnweb.com/artists.php',
#  'http://testphp.vulnweb.com/cart.php',
#  'http://testphp.vulnweb.com/categories.php',
#  'http://testphp.vulnweb.com/disclaimer.php',
#  'http://testphp.vulnweb.com/guestbook.php',
#  'http://testphp.vulnweb.com/hpp',
#  'http://testphp.vulnweb.com/index.php',
#  'http://testphp.vulnweb.com/login.php',
#  'http://testphp.vulnweb.com/privacy.php',
#  'http://testphp.vulnweb.com/userinfo.php'}

# %%
forms
# Out:
# {'http://testphp.vulnweb.com/search.php?test=query': ['searchFor', 'goButton'],
#  'http://testphp.vulnweb.com/userinfo.php/userinfo.php': ['uname', 'pass'],
#  'http://testphp.vulnweb.com/userinfo.php/search.php?test=query': ['searchFor',
#   'goButton'],
#  'http://testphp.vulnweb.com/login.php/userinfo.php': ['uname', 'pass'],
#  'http://testphp.vulnweb.com/login.php/search.php?test=query': ['searchFor',
#   'goButton'],
#  'http://testphp.vulnweb.com/artists.php/search.php?test=query': ['searchFor',
#   'goButton'],
#  'http://testphp.vulnweb.com/cart.php/search.php?test=query': ['searchFor',
#   'goButton']}
